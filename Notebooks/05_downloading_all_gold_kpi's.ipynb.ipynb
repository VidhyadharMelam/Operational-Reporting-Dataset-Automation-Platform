# %% [markdown]
# # gold_sla_kpi.csv

# %%
# Example: SLA KPI
df = spark.table("gold_sla_kpi")

# Convert to Pandas and save locally in notebook environment
df.toPandas().to_csv("gold_sla_kpi.csv", index=False)

# %% [markdown]
# #gold_processing_kpi.csv

# %%
# Load Gold Processing KPI table
df_processing = spark.table("gold_processing_kpi")

# Convert to Pandas and save as CSV locally
df_processing.toPandas().to_csv("gold_processing_kpi.csv", index=False)

# %% [markdown]
# # gold_dept_sla_kpi.csv

# %%
# Load Gold Department SLA KPI table
df_dept_sla = spark.table("gold_dept_sla_kpi")

# Convert to Pandas and save as CSV locally
df_dept_sla.toPandas().to_csv("gold_dept_sla_kpi.csv", index=False)

# %% [markdown]
# # gold_priority_sla_kpi.csv

# %%
# Load Gold Priority SLA KPI table
df_priority_sla = spark.table("gold_priority_sla_kpi")

# Convert to Pandas and save as CSV locally
df_priority_sla.toPandas().to_csv("gold_priority_sla_kpi.csv", index=False)

# %% [markdown]
# # gold_dept_priority_sla_kpi.csv

# %%
# Load Gold Department + Priority SLA KPI table
df_dept_priority_sla = spark.table("gold_dept_priority_sla_kpi")

# Convert to Pandas and save as CSV locally
df_dept_priority_sla.toPandas().to_csv("gold_dept_priority_sla_kpi.csv", index=False)

# %% [markdown]
# # gold_daily_sla_kpi.csv

# %%
# Load Gold Daily SLA KPI table
df_daily_sla = spark.table("gold_daily_sla_kpi")

# Convert to Pandas and save as CSV locally
df_daily_sla.toPandas().to_csv("gold_daily_sla_kpi.csv", index=False)

# %% [markdown]
# # gold_weekly_processing_kpi.csv

# %%
# Load Gold Weekly Processing KPI table
df_weekly_processing = spark.table("gold_weekly_processing_kpi")

# Convert to Pandas and save as CSV locally
df_weekly_processing.toPandas().to_csv("gold_weekly_processing_kpi.csv", index=False)

# %% [markdown]
# # gold_processing_anomalies.csv

# %%
# Load Gold Processing Anomalies table
df_processing_anomalies = spark.table("gold_processing_anomalies")

# Convert to Pandas and save as CSV locally
df_processing_anomalies.toPandas().to_csv("gold_processing_anomalies.csv", index=False)

# %% [markdown]
# # gold_sla_anomalies.csv

# %%
# Load Gold SLA Anomalies table
df_sla_anomalies = spark.table("gold_sla_anomalies")

# Convert to Pandas and save as CSV locally
df_sla_anomalies.toPandas().to_csv("gold_sla_anomalies.csv", index=False)

# %% [markdown]
# # gold_sla_forecast.csv

# %%
# Load Gold SLA Forecast table
df_sla_forecast = spark.table("gold_sla_forecast")

# Convert to Pandas and save as CSV locally
df_sla_forecast.toPandas().to_csv("gold_sla_forecast.csv", index=False)

# %% [markdown]
# # gold_processing_forecast.csv

# %%
# Load Gold Processing Forecast table
df_processing_forecast = spark.table("gold_priority_processing_kpi")

# Convert to Pandas and save as CSV locally
df_processing_forecast.toPandas().to_csv("gold_priority_processing.csv", index=False)

# %% [markdown]
# # gold_scenario_sla_kpi.csv

# %%
# Load Gold Scenario SLA KPI table
df_scenario_sla = spark.table("gold_scenario_sla_kpi")

# Convert to Pandas and save as CSV locally
df_scenario_sla.toPandas().to_csv("gold_scenario_sla_kpi.csv", index=False)
